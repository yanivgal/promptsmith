  

      “Because the Miranda rule concerns the introduction of evidence at trial, a suspect may not sue the police officer under Section 1983 for violating that rule,” Solicitor General Elizabeth Prelogar argued in court papers.  
   
      Lawyers for Tekoh argued that Vega refused to accept Tekoh’s denials and that “with a hand resting on his firearm,” Vega threatened to report Tekoh and his family members to immigration. Tekoh has a green card, and deportation could lead to persecution in Cameroon. 
   
      Paul Hoffman, a lawyer for Tekoh, said that Vega was “the central actor in the chain of events leading directly to the statement being introduced at trial.”"""

# %%
from promptsmith.tasks.bulletize_text_with_proffesion_injection import BulletizeTextWithStyle

# %% [markdown]
# # researcher/academia

# %%
bulletize_ra_sig = BulletizeTextWithStyle(proffesion="children book author")
print(bulletize_ra_sig.__doc__)
# Out:
# You are an expert children book author writer.
#
#
#     **Task**
#     Rewrite the supplied text as a structured, Markdown-formatted outline.
#
#     **Title rule (T)**
#     • If the source already has a clear title **or** the text spans several distinct sections (e.g., report, article, interview), add one H1 heading (`# …`) at the very top.
#     • Keep the title ≤ 8 words and descriptive.
#     • Otherwise, skip the title entirely.
#
#     **Format rules**
#     0. Start with one sentence (≤ 15 words) that summarizes the entire text. *Do not add any label.*
#     1. Add an H2 heading (`## …`) for each logical block.
#     2. Under every heading supply **3-8** concise bullets:
#         • capture every unique name, date, statistic, money figure, or quote (< 20 words)
#         • if the source pairs values (e.g., Importance vs Ability), show both in one bullet
#         • begin a bullet with a **bold label** when the sentence naturally has one (e.g., **Time Management:**)
# ...

# %%
bulletize_with_ra = dspy.ChainOfThought(bulletize_ra_sig)
result = bulletize_with_ra(input_text=text_to_bulletize)
result.output_text
# Out:
# "# Faculty Perceptions of Online Teaching Competencies\n\nThe study investigates the relationship between faculty perceptions of online teaching competencies and their ability to teach online.\n\n## Relationship Between Importance and Ability\n- **Research Question:** What is the strength and direction of the relationship between faculty's perceptions of the importance of competencies and their ability to teach online?\n- Descriptive statistics (mean and standard deviation) were reported for four competency dimensions: \n  - **Course Design:** \n    - Manage grades online (M = 4.73)\n    - Creating online assignments (M = 4.68)\n  - **Course Communication:** \n    - Responding to student questions promptly (M = 4.79)\n    - Providing feedback on assignments (M = 4.65)\n  - **Time Management:** \n    - Scheduling time to design the course (M = 4.65)\n    - Spending weekly hours to grade assignments (M = 4.54)\n  - **Technical Competency:** \n    - Complete basic computer operations (M
# ...

# %% [markdown]
# # lawyer

# %%
bulletize_l_sig = BulletizeTextWithStyle(proffesion="lawyer")
print(bulletize_l_sig.__doc__)
# Out:
# You are an expert lawyer writer.
#
#
#     **Task**
#     Rewrite the supplied text as a structured, Markdown-formatted outline.
#
#     **Title rule (T)**
#     • If the source already has a clear title **or** the text spans several distinct sections (e.g., report, article, interview), add one H1 heading (`# …`) at the very top.
#     • Keep the title ≤ 8 words and descriptive.
#     • Otherwise, skip the title entirely.
#
#     **Format rules**
#     0. Start with one sentence (≤ 15 words) that summarizes the entire text. *Do not add any label.*
#     1. Add an H2 heading (`## …`) for each logical block.
#     2. Under every heading supply **3-8** concise bullets:
#         • capture every unique name, date, statistic, money figure, or quote (< 20 words)
#         • if the source pairs values (e.g., Importance vs Ability), show both in one bullet
#         • begin a bullet with a **bold label** when the sentence naturally has one (e.g., **Time Management:**)
# ...

# %%
bulletize_with_l = dspy.ChainOfThought(bulletize_l_sig)
result = bulletize_with_l(input_text=text_to_bulletize)
result.output_text
# Out:
# "# Supreme Court Ruling on Miranda Rights\n\nThe Supreme Court has limited the enforcement of Miranda rights, affecting civil lawsuits against police officers.\n\n## Ruling Overview\n- The Supreme Court ruled that suspects cannot sue police officers for damages if not warned of their Miranda rights.\n- This ruling reduces protections against self-incrimination by eliminating potential damages for violations.\n- The failure to provide Miranda warnings does not expose officers to civil lawsuits, but evidence can still be excluded in criminal trials.\n\n*The ruling clarifies the limitations of Miranda rights in civil contexts.*\n\n---\n\n## Key Statements\n- **Steve Vladeck:** The ruling makes it harder to enforce Miranda rights; the only remedy is suppression of statements.\n- **Justice Samuel Alito:** A violation of Miranda is not a violation of the Fifth Amendment; no justification for a right to sue.\n- **Justice Elena Kagan:** The ruling strips individuals of remedies for violation
# ...

# %% [markdown]
# # Supreme Court Ruling on Miranda Rights
#
# The Supreme Court has limited the enforcement of Miranda rights, affecting civil lawsuits against police officers.
#
# ## Ruling Overview
# - The Supreme Court ruled that suspects cannot sue police officers for damages if not warned of their Miranda rights.
# - This ruling reduces protections against self-incrimination by eliminating potential damages for violations.
# - The failure to provide Miranda warnings does not expose officers to civil lawsuits, but evidence can still be excluded in criminal trials.
#
# *The ruling clarifies the limitations of Miranda rights in civil contexts.*
#
# ---
#
# ## Key Statements
# - **Steve Vladeck:** The ruling makes it harder to enforce Miranda rights; the only remedy is suppression of statements.
# - **Justice Samuel Alito:** A violation of Miranda is not a violation of the Fifth Amendment; no justification for a right to sue.
# - **Justice Elena Kagan:** The ruling strips individuals of remedies for violations of Miranda rights.
#
# *Key statements highlight differing judicial perspectives on the ruling's implications.*
#
# ---
#
# ## Case Background
# - The case involved Terence Tekoh, accused of sexually assaulting a patient in 2014.
# - The issue was whether Tekoh could sue for damages due to not receiving Miranda warnings.
# - Lower courts had conflicting decisions on this matter.
#
# *The case background provides context for the Supreme Court's ruling.*
#
# ---
#
# ## Arguments Presented
# - **Carlos Vega's Defense:** Tekoh's statement was consensual; he was not in custody.
# - **Tekoh's Lawyers:** Claimed he was coerced into confessing under duress.
# - **Roman Martinez:** Argued that a Miranda violation does not equate to a Fifth Amendment violation.
#
# *Arguments from both sides illustrate the complexities of the case.*
#
# ---
#
# ## Implications of the Ruling
# - The ruling may burden police departments with potential lawsuits for lawful actions.
# - **Martinez's View:** The ruling confirms that Vega acted in good faith during the investigation.
# - **Solicitor General Elizabeth Prelogar:** Emphasized that the Miranda rule pertains to evidence admission, not civil lawsuits.
#
# *The implications of the ruling suggest significant changes in law enforcement practices and civil rights.*
#
# ---
#
# ## Additional Context
# - Tekoh's lawyers argued that Vega threatened him regarding immigration status.
# - **Paul Hoffman:** Asserted that Vega was central to the events leading to the statement's introduction at trial.
#
# *Additional context highlights the personal stakes involved in the case.*

# %% [markdown]
# # designer

# %%
bulletize_sarcastic_sig = BulletizeTextWithStyle(proffesion="designer")
print(bulletize_sarcastic_sig.__doc__)
# Out:
# You are an expert designer writer.
#
#
#     **Task**
#     Rewrite the supplied text as a structured, Markdown-formatted outline.
#
#     **Title rule (T)**
#     • If the source already has a clear title **or** the text spans several distinct sections (e.g., report, article, interview), add one H1 heading (`# …`) at the very top.
#     • Keep the title ≤ 8 words and descriptive.
#     • Otherwise, skip the title entirely.
#
#     **Format rules**
#     0. Start with one sentence (≤ 15 words) that summarizes the entire text. *Do not add any label.*
#     1. Add an H2 heading (`## …`) for each logical block.
#     2. Under every heading supply **3-8** concise bullets:
#         • capture every unique name, date, statistic, money figure, or quote (< 20 words)
#         • if the source pairs values (e.g., Importance vs Ability), show both in one bullet
#         • begin a bullet with a **bold label** when the sentence naturally has one (e.g., **Time Management:**)
# ...

# %%
bulletize_with_sarcastic_style = dspy.ChainOfThought(bulletize_sarcastic_sig)
result = bulletize_with_sarcastic_style(input_text=text_to_bulletize)
result.output_text
# Out:
# "# Supreme Court Ruling on Miranda Rights\n\nThe Supreme Court has limited the enforcement of Miranda rights, affecting civil lawsuits against police officers.\n\n## Ruling Overview\n- **Date of Ruling:** Thursday\n- **Key Decision:** Suspects cannot sue police for damages if not warned of their right to remain silent.\n- **Impact:** Reduces protections against self-incrimination; does not affect evidence exclusion in criminal trials.\n\n*The ruling alters the landscape of civil rights related to Miranda warnings.*\n\n---\n\n## Justices' Perspectives\n- **Justice Samuel Alito:** \n  - Violation of Miranda is not a violation of the Fifth Amendment.\n  - No justification for expanding Miranda to allow lawsuits.\n- **Justice Elena Kagan:** \n  - Ruling strips individuals of remedies for Miranda violations.\n\n*The justices' opinions highlight the divide on the interpretation of Miranda rights.*\n\n---\n\n## Case Background\n- **Defendant:** Terence Tekoh, accused of sexual assault in 20
# ...

# %% [markdown]
# # Supreme Court Ruling on Miranda Rights
#
# The Supreme Court has limited the enforcement of Miranda rights, affecting civil lawsuits against police officers.
#
# ## Ruling Overview
# - **Date of Ruling:** Thursday
# - **Key Decision:** Suspects cannot sue police for damages if not warned of their right to remain silent.
# - **Impact:** Reduces protections against self-incrimination; does not affect evidence exclusion in criminal trials.
#
# *The ruling alters the landscape of civil rights related to Miranda warnings.*
#
# ---
#
# ## Justices' Perspectives
# - **Justice Samuel Alito:**
#   - Violation of Miranda is not a violation of the Fifth Amendment.
#   - No justification for expanding Miranda to allow lawsuits.
# - **Justice Elena Kagan:**
#   - Ruling strips individuals of remedies for Miranda violations.
#
# *The justices' opinions highlight the divide on the interpretation of Miranda rights.*
#
# ---
#
# ## Case Background
# - **Defendant:** Terence Tekoh, accused of sexual assault in 2014.
# - **Key Issue:** Can a defendant sue for damages if not read Miranda rights?
# - **Lower Courts:** Split on the issue.
#
# *The case illustrates the complexities surrounding Miranda rights and civil liability.*
#
# ---
#
# ## Details of the Incident
# - **Officer Involved:** Carlos Vega, failed to read Tekoh his rights.
# - **Arguments:**
#   - Vega's lawyers: Tekoh's statement was consensual; he was not in custody.
#   - Tekoh's lawyers: He was coerced into confessing.
#
# *The differing accounts of the incident raise questions about police conduct and rights.*
#
# ---
#
# ## Legal Arguments
# - **Roman Martinez (Vega's Lawyer):**
#   - Establishing a Miranda violation does not equate to a Fifth Amendment violation.
#   - Miranda is a procedural rule, not a right.
# - **Paul Hoffman (Tekoh's Lawyer):**
#   - Vega threatened Tekoh, impacting his ability to deny the allegations.
#
# *The legal arguments reflect the tension between procedural rules and individual rights.*
#
# ---
#
# ## Implications of the Ruling
# - **Martinez's View:**
#   - Ruling prevents burdens on police departments from lawsuits.
#   - Confirms that good-faith police actions cannot lead to civil suits.
# - **Solicitor General Elizabeth Prelogar:**
#   - Failure to give a Miranda warning does not allow for lawsuits under Section 1983.
#
# *The ruling has significant implications for law enforcement and civil rights litigation.*
