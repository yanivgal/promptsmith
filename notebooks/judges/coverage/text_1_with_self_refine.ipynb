# %%
TEXT_TO_JUDGE = "../../../data/text_01.txt"

# %%
with open(TEXT_TO_JUDGE, "r") as f:
    text_to_judge = f.read()

# %%
from promptsmith.dspy_init import get_dspy
dspy, lm = get_dspy()

# %%
from promptsmith.judges.judge_coverage import JudgeCoverage
judge = dspy.Predict(JudgeCoverage)

# %% [markdown]
# just for fun, let's see how the judge handles the text before it's even bulletized:

# %%
r1 = judge(input_text=text_to_judge, output_text=text_to_judge)

print("Reasoning:", r1.reasoning)
print("Score:", r1.score)
# Out:
# Reasoning: The output text captures all the key ideas from the original input. It retains the main research questions regarding the relationship between faculty perceptions of competencies and their ability to teach online, as well as the demographic factors influencing these perceptions. The detailed statistics for each competency dimension, including the highest-rated items and their means, are preserved accurately. Additionally, the findings regarding the weak positive relationship between perceived importance and ability, as well as the demographic analysis results, are included. There are no significant omissions or glossed-over points, and the output remains faithful to the original scope and content.
# Score: 1.0

# %% [markdown]
# ---

# %%
from promptsmith.tasks.bad_to_good.bulletize_text_1 import BulletizeText as simple_bulletizer
from promptsmith.tasks.bad_to_good.bulletize_text_2 import BulletizeText as better_bulletizer

simple_bulletizer = dspy.Predict(simple_bulletizer)
better_bulletizer = dspy.Predict(better_bulletizer)

# %%
bulletized_text_1_simple = simple_bulletizer(input_text=text_to_judge)

# %%
r2 = judge(input_text=text_to_judge, output_text=bulletized_text_1_simple)

print("Reasoning:", r2.reasoning)
print("Score:", r2.score)
# Out:
# Reasoning: The output text effectively captures the key ideas from the original input. It summarizes the first research question regarding the relationship between faculty perceptions of competencies and their ability to teach online, including the descriptive statistics for each competency area. The highest-rated items for course design, communication, time management, and technical competency are all included, along with their respective means. The findings indicating the need for more support in course design and communication are also preserved.
#
# The output also addresses the second research question about demographic factors, detailing the demographics analyzed and the significant differences found. However, it does not explicitly mention the lack of significant differences in academic rank and online teaching methods, which is a minor detail that could enhance completeness. Overall, the output maintains a high level of coverage of the original ideas.
# Score: 0.9

# %%
bulletized_text_1_better = better_bulletizer(input_text=text_to_judge)

# %%
r3 = judge(input_text=text_to_judge, output_text=bulletized_text_1_better)

print("Reasoning:", r3.reasoning)
print("Score:", r3.score)
# Out:
# Reasoning: The output text captures the main ideas from the input text effectively. It addresses both research questions, summarizing the relationship between faculty perceptions of teaching competencies and their ability to teach online, as well as the demographic factors influencing these perceptions. Key statistics and findings are included, such as the mean ratings for various competencies and the results of the ANOVA analysis. However, some specific details, such as the exact values for the means in the second part of the course design and communication competencies, are not included in the output. Overall, the major points are preserved, but a few specific details are glossed over.
# Score: 0.85

# %%
print(bulletized_text_1_better.output_text)
# Out:
# # Faculty Perceptions of Online Teaching Competencies
#
# The study investigates the relationship between faculty perceptions of teaching competencies and their ability to teach online.
#
# ## Research Question 1: Relationship Between Perceptions and Ability
# **What is the strength and direction of the relationship between faculty's perceptions and their ability to teach online?**
# - **Descriptive Statistics:** Reported mean and standard deviation for competencies in Table 2, page 23.
# - **Course Design Competency:**
#   - Manage grades online: M = 4.73
#   - Creating online assignments: M = 4.68
# - **Course Communication Competency:**
#   - Responding to student questions promptly: M = 4.79
#   - Providing feedback on assignments: M = 4.65
# - **Time Management Competency:**
#   - Scheduling time to design the course: M = 4.65
#   - Spending weekly hours to grade assignments: M = 4.54
# - **Technical Competency:**
#   - Complete basic computer operations: M = 4.74
# ...

# %% [markdown]
# # Faculty Perceptions of Online Teaching Competencies
# The study investigates the relationship between faculty perceptions of teaching competencies and their ability to teach online.
#
# ## Research Question 1: Relationship Between Perceptions and Ability
# **What is the strength and direction of the relationship between faculty's perceptions of the importance of course design, communication, time management, and technical competency, and their ability to teach online?**
# - **Descriptive Statistics:** Reported mean and standard deviation for each competency dimension in Table 2 (page 23).
# - **Course Design Competency:**
#   - Manage grades online: M = 4.73
#   - Creating online assignments: M = 4.68
# - **Course Communication Competency:**
#   - Responding to student questions promptly: M = 4.79
#   - Providing feedback on assignments: M = 4.65
# - **Time Management Competency:**
#   - Scheduling time to design the course: M = 4.65
#   - Spending weekly hours to grade assignments: M = 4.54
# - **Technical Competency:**
#   - Complete basic computer operations: M = 4.74
#   - Navigating within the course in the LMS: M = 4.67
# - **Findings:** High ratings in importance for course design and communication suggest a need for more faculty support.
# - **Additional Ratings:**
#   - Course Design: Manage grades online (M = 4.61), Create online assignments (M = 4.60)
#   - Course Communication: Sending announcements/email reminders (M = 4.82), Use email to communicate (M = 4.79)
#   - Time Management: Schedule weekly hours (M = 4.39), Spend weekly hours grading (M = 4.37)
#   - Technical Competency: Basic computer operations (M = 4.64), Navigate LMS (M = 4.36)
# - **Statistical Analysis:** Weak positive relationship between perceived importance and ability, r(223) = .249, p < .001.
#
# This section highlights the strong perceptions of importance and ability among faculty regarding online teaching competencies.
#
# ---
#
# ## Research Question 2: Demographic Factors
# **What demographic factors are related to faculty's perceptions of the importance of course design, communication, time management, and technical competency, and their ability to teach online?**
# - **Demographic Information Collected:** Gender, academic rank, online teaching methods, and level taught.
# - **Descriptive Statistics:** Presented in Table 5 (page 32, Chapter IV).
# - **ANOVA Results:**
#   - Significant differences in gender and level taught regarding importance of competencies.
#   - No significant differences in gender, academic rank, and online teaching methods.
#   - Significant differences in level taught based on perceptions of ability to teach online.
# - **Other Findings:** No significant differences in academic rank and online teaching methods.
#
# This section provides insights into how demographic factors influence faculty perceptions of online teaching competencies.

# %% [markdown]
# # self-refine using judges feedback

# %% [markdown]
# [Self-Refine: Iterative Refinement with Self-Feedback](https://arxiv.org/abs/2303.17651)

# %% [markdown]
# ### manually gave it to chatgpt and fixed `Section Closing Line`

# %%
t = """
# Faculty Perceptions of Online Teaching Competencies
The study investigates the relationship between faculty perceptions of teaching competencies and their ability to teach online.

## Research Question 1: Relationship Between Perceptions and Ability
**What is the strength and direction of the relationship between faculty's perceptions of the importance of course design, communication, time management, and technical competency, and their ability to teach online?**
- **Descriptive Statistics:** Reported mean and standard deviation for each competency dimension in Table 2 (page 23).
- **Course Design Competency:**
  - Manage grades online: M = 4.73
  - Creating online assignments: M = 4.68
- **Course Communication Competency:**
  - Responding to student questions promptly: M = 4.79
  - Providing feedback on assignments: M = 4.65
- **Time Management Competency:**
  - Scheduling time to design the course: M = 4.65
  - Spending weekly hours to grade assignments: M = 4.54
- **Technical Competency:**
  - Complete basic computer operations: M = 4.74
  - Navigating within the course in the LMS: M = 4.67
- **Findings:** High ratings in importance for course design and communication suggest a need for more faculty support.
- **Additional Ratings:**
  - Course Design: Manage grades online (M = 4.61), Create online assignments (M = 4.60)
  - Course Communication: Sending announcements/email reminders (M = 4.82), Use email to communicate (M = 4.79)
  - Time Management: Schedule weekly hours (M = 4.39), Spend weekly hours grading (M = 4.37)
  - Technical Competency: Basic computer operations (M = 4.64), Navigate LMS (M = 4.36)
- **Statistical Analysis:** Weak positive relationship between perceived importance and ability, r(223) = .249, p < .001.

*These findings suggest that faculty feel confident in key areas like communication and course design, though the relationship between perceived importance and ability remains modest.*

---

## Research Question 2: Demographic Factors
**What demographic factors are related to faculty's perceptions of the importance of course design, communication, time management, and technical competency, and their ability to teach online?**
- **Demographic Information Collected:** Gender, academic rank, online teaching methods, and level taught.
- **Descriptive Statistics:** Presented in Table 5 (page 32, Chapter IV).
- **ANOVA Results:**
  - Significant differences in gender and level taught regarding importance of competencies.
  - No significant differences in gender, academic rank, and online teaching methods.
  - Significant differences in level taught based on perceptions of ability to teach online.
- **Other Findings:** No significant differences in academic rank and online teaching methods.

*Demographic analysis showed that gender and level taught play a role in perceived importance and ability, while other factors like rank and teaching methods showed no significant impact.*
"""

r4 = judge(text=t)

print("Reasoning:", r4.reasoning)
print("Score:", r4.score)
# Out:
# 2025/05/26 10:14:32 WARNING dspy.predict.predict: Not all input fields were provided to module. Present: []. Missing: ['input_text', 'output_text'].
# Reasoning: The rewritten text captures the main ideas from the original input effectively. It includes all major points and maintains the overall scope of the original message. There are no significant ideas missing or glossed over, and the rephrasing does not alter the intended meaning. Therefore, the coverage is excellent.
# Score: 1.0

# %% [markdown]
# ### manually gave it to chatgpt and fixed the `Bullets Inside Each Section`

# %%
t = """
# Faculty Perceptions of Online Teaching Competencies
This study explores how faculty perceive key online teaching competencies—and how those perceptions relate to their ability to teach online.

---

## Research Question 1: Perceptions vs. Ability  
**What is the relationship between faculty perceptions of online teaching competencies (importance) and their self-reported ability to teach online?**

- **Competency Areas Evaluated:**
  - Course Design
  - Course Communication
  - Time Management
  - Technical Competency

- **Descriptive Statistics:** See Table 2 (page 23) for means and standard deviations per item.

- **Top-Rated Items (Importance vs. Ability):**

  **Course Design**  
  - *Importance:* Manage grades online (M = 4.73), Create online assignments (M = 4.68)  
  - *Ability:* Manage grades online (M = 4.61), Create online assignments (M = 4.60)

  **Course Communication**  
  - *Importance:* Respond to student questions promptly (M = 4.79), Provide feedback (M = 4.65)  
  - *Ability:* Send announcements/email reminders (M = 4.82), Use email to communicate (M = 4.79)

  **Time Management**  
  - *Importance:* Schedule course design time (M = 4.65), Grade assignments weekly (M = 4.54)  
  - *Ability:* Facilitate weekly (M = 4.39), Grade assignments weekly (M = 4.37)

  **Technical Competency**  
  - *Importance:* Basic computer operations (M = 4.74), Navigate LMS (M = 4.67)  
  - *Ability:* Basic computer operations (M = 4.64), Navigate LMS (M = 4.36)

- **Key Finding:**  
  Faculty rated both importance and ability highly for course design and communication, but overall there was only a weak positive correlation between perceived importance and ability (r(223) = .249, p < .001).

---

## Research Question 2: Role of Demographics  
**Which demographic factors affect faculty perceptions and ability to teach online?**

- **Demographics Analyzed:** Gender, academic rank, online teaching methods, level taught  
- **Source:** Descriptive data in Table 5 (page 32, Chapter IV)

- **Key Findings from ANOVA:**
  - **Importance:** Significant differences found based on gender and level taught.
  - **Ability:** Significant difference found based on level taught only.
  - **No Significant Differences:** Academic rank and online teaching methods.

*Overall, gender and the level taught emerged as meaningful factors in faculty perceptions, while other demographic variables showed no significant impact.*
"""

r5 = judge(text=t)

print("Reasoning:", r5.reasoning)
print("Score:", r5.score)
# Out:
# 2025/05/26 10:14:37 WARNING dspy.predict.predict: Not all input fields were provided to module. Present: []. Missing: ['input_text', 'output_text'].
# Reasoning: The rewritten text captures the main ideas from the original input effectively. It includes all major points and maintains the overall message. There are no significant ideas missing, and the scope of the output remains faithful to the original content. The rephrasing does not gloss over any important details, ensuring a comprehensive coverage of the original text.
# Score: 1.0

# %% [markdown]
# ### final bulletized version:

# %% [markdown]
# # Faculty Perceptions of Online Teaching Competencies
# This study explores how faculty perceive key online teaching competencies—and how those perceptions relate to their ability to teach online.
#
# ---
#
# ## Research Question 1: Perceptions vs. Ability
# **What is the relationship between faculty perceptions of online teaching competencies (importance) and their self-reported ability to teach online?**
#
# - **Competency Areas Evaluated:**
#   - Course Design
#   - Course Communication
#   - Time Management
#   - Technical Competency
#
# - **Descriptive Statistics:** See Table 2 (page 23) for means and standard deviations per item.
#
# - **Top-Rated Items (Importance vs. Ability):**
#
#   **Course Design**
#   - *Importance:* Manage grades online (M = 4.73), Create online assignments (M = 4.68)
#   - *Ability:* Manage grades online (M = 4.61), Create online assignments (M = 4.60)
#
#   **Course Communication**
#   - *Importance:* Respond to student questions promptly (M = 4.79), Provide feedback (M = 4.65)
#   - *Ability:* Send announcements/email reminders (M = 4.82), Use email to communicate (M = 4.79)
#
#   **Time Management**
#   - *Importance:* Schedule course design time (M = 4.65), Grade assignments weekly (M = 4.54)
#   - *Ability:* Facilitate weekly (M = 4.39), Grade assignments weekly (M = 4.37)
#
#   **Technical Competency**
#   - *Importance:* Basic computer operations (M = 4.74), Navigate LMS (M = 4.67)
#   - *Ability:* Basic computer operations (M = 4.64), Navigate LMS (M = 4.36)
#
# - **Key Finding:**
#   Faculty rated both importance and ability highly for course design and communication, but overall there was only a weak positive correlation between perceived importance and ability (r(223) = .249, p < .001).
#
# ---
#
# ## Research Question 2: Role of Demographics
# **Which demographic factors affect faculty perceptions and ability to teach online?**
#
# - **Demographics Analyzed:** Gender, academic rank, online teaching methods, level taught
# - **Source:** Descriptive data in Table 5 (page 32, Chapter IV)
#
# - **Key Findings from ANOVA:**
#   - **Importance:** Significant differences found based on gender and level taught.
#   - **Ability:** Significant difference found based on level taught only.
#   - **No Significant Differences:** Academic rank and online teaching methods.
#
# *Overall, gender and the level taught emerged as meaningful factors in faculty perceptions, while other demographic variables showed no significant impact.*
