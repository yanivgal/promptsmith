# %% [markdown]
# * show how a simple change in the prompt (adding the profession from the dataset as is) does not give sufficient result (or is it?)'
# * show that the more complex style guidelines improve the "styling" for the better
# * check how refinement handle the style, if we need another judge
# * check this flow as well: bulletize -> refine -> only then set different styles
# * ask Noa if they have existing phrasing styles based on proffesion?
# * check a validator for the refinement process that checks if the things the refiner said that he changes actually were changed (suggest train a model not only on chain of thoughts, but also on verification of the results)

# %%
from promptsmith.dspy_init import get_dspy
dspy, lm = get_dspy()

# %%
from promptsmith.tasks.bulletize_text import BulletizeTextWithStyle

text_to_bulletize = """
The Supreme Court limited the ability to enforce Miranda rights in a ruling Thursday that said that suspects who are not warned about their right to remain silent cannot sue a police officer for damages under federal civil rights law even if the evidence was ultimately used against them in their criminal trial.   
   
      The court’s ruling will cut back on an individual’s protections against self-incrimination by barring the potential to obtain damages. It also means that the failure to administer the warning will not expose a law enforcement officer to potential damages in a civil lawsuit. It will not impact, however, the exclusion of such evidence at a criminal trial.  
   
      The court clarified that while the Miranda warning protects a constitutional right, the warning itself is not a right that would trigger the ability to bring a civil lawsuit. 
  

      “Today’s ruling doesn’t get rid of the Miranda right,” said Steve Vladeck, CNN Supreme Court analyst and professor at the University of Texas School of Law. “But it does make it far harder to enforce. Under this ruling, the only remedy for a violation of Miranda is to suppress statements obtained from a suspect who’s not properly advised of his right to remain silent. But if the case never goes to trial, or if the government never seeks to use the statement, or if the statement is admitted notwithstanding the Miranda violation, there’s no remedy at all for the government’s misconduct.” 
  

      Justice Samuel Alito, joined by the five other Republican-appointed justices, said that a violation of the Miranda right “is not itself a violation of the Fifth Amendment,” and that “we see no justification for expanding Miranda to confer a right to sue,” under the relevant statute.  
   
      Justice Elena Kagan, joined by the other liberal justices, said that the court’s ruling was stripping “individuals of the ability to seek a remedy for violations of the right recognized in Miranda.” 
  

      The case involved Terence Tekoh, a hospital worker who was accused of sexually assaulting an immobilized female patient at a local hospital in 2014. 
   
      At issue was not whether a defendant must be read his Miranda rights, but whether he can sue an officer for damages if he doesn’t receive the Miranda warning for evidence introduced in a criminal proceeding. Lower courts have split on the issue.  
   
      Carlos Vega, a Los Angeles County sheriff deputy, questioned Tekoh, although he failed to read him his rights as required by the 1966 precedent of Miranda v. Arizona, where the court held that a defendant must be warned of a “right to remain silent.” Under that precedent, without the Miranda warning, criminal trial courts are generally barred from admitting self-incriminating statements made while the defendant was in custody.  
  

      Lawyers for Vega said Tekoh’s statement was entirely consensual and voluntary, and he was not technically “in custody” at the time, while Tekoh’s lawyers contended he was bullied into confessing in a windowless room.  
   
      Roman Martinez, a lawyer for Vega, said that Tekoh couldn’t bring his claim because establishing a violation of Miranda does not establish a violation of the Fifth Amendment.  
   
      “Miranda creates a procedural rule barring prosecutors from introducing—and courts from admitting—certain unwarned statements as a part of the prosecution’s case-in-chief at a criminal trial,” Martinez argued in court papers. 
   
      For Martinez, the Miranda warning is a constitutional rule, it is not a right, and under that interpretation the lawsuit cannot go forward. “Miranda does not prohibit taking unwarned statements; it merely forbids the subsequent admission of such statements at trial,” Martinez argued. 
   
      He said an appeals court ruling that went in favor of Tekoh would “saddle police departments nationwide with extraordinary burdens in connection with lawful and appropriate investigative work.” Any police interaction, according to Martinez, could give rise to a private lawsuit “even where the police officer has acted entirely lawfully.”  
  

      Martinez commended the court’s ruling Thursday, saying it “confirms that Deputy Vega cannot be sued for his good-faith effort to investigate the alleged sexual assault of a defenseless hospital patient.”  
   
      “As the Court explained, the landmark Miranda decision establishes an important prophylactic rule protecting the Fifth Amendment right against compelled self-incrimination,” he added. “But the failure to give a Miranda warning does not automatically equate to a violation of the Fifth Amendment.”
  

      “Because the Miranda rule concerns the introduction of evidence at trial, a suspect may not sue the police officer under Section 1983 for violating that rule,” Solicitor General Elizabeth Prelogar argued in court papers.  
   
      Lawyers for Tekoh argued that Vega refused to accept Tekoh’s denials and that “with a hand resting on his firearm,” Vega threatened to report Tekoh and his family members to immigration. Tekoh has a green card, and deportation could lead to persecution in Cameroon. 
   
      Paul Hoffman, a lawyer for Tekoh, said that Vega was “the central actor in the chain of events leading directly to the statement being introduced at trial.”"""

# %%
len(text_to_bulletize)
# Out:
# 5293

# %% [markdown]
# # childish

# %%
from promptsmith.tasks.bulletize_text import BulletizeTextWithStyle

bulletize_childish_sig = BulletizeTextWithStyle(style="childish")

print(bulletize_childish_sig.__doc__)
# Out:
#     You are an expert technical writer.
#
#     **Task**
#     Rewrite the supplied text as a structured, Markdown-formatted outline.
#
#
# **Style Guidelines**
# You are a cheerful, playful narrator writing for young children (ages 6–9). Use very simple words, short sentences, and a friendly tone. Be energetic, curious, and fun! Use expressions like 'Wow!', 'Let’s find out!', 'Isn’t that cool?', or 'Uh-oh!'. Speak directly to the reader like they’re on an adventure with you. Don’t use big words. Always make it feel like playtime.
#
# **Title rule (T)**
#     • If the source already has a clear title **or** the text spans several distinct sections (e.g., report, article, interview), add one H1 heading (`# …`) at the very top.
#     • Keep the title ≤ 8 words and descriptive.
#     • Otherwise, skip the title entirely.
#
#     **Format rules**
#     0. Start with one sentence (≤ 15 words) that summarizes the entire text. *Do not add any label.*
#     1. Add an H2 heading (`## …`) for each logical block.
#     2. Under every heading supply **3-8** concise bullets:
#         • capture every unique name, date, statistic, money figure, or quote (< 20 words)
#         • if the source pairs values (e.g., Importance vs Ability), show both in one bullet
#         • begin a bullet with a **bold label** when the sentence naturally has one (e.g., **Time Management:**)
#         • nest bullets where helpful to show hierarchy or examples
#         • if a block would have < 3 bullets, merge it with a neighbor or expand a point so the section stands alone
#     3. When the source contains an explicit question, place that question on its own line in **bold** right before the bullets that answer it.
#     4. Strip filler, greetings, ads, and repetition.
#     5. For transcripts, group by topic (not speaker turns) and omit sponsor segments.
#     6. End each section with one italic sentence that summarizes the block. *Do not write “Takeaway:”.*
#     7. Separate major sections with three dashes (`---`) on a line by themselves.
#     8. Output only the formatted outline—no extra commentary.

# %%
bulletize_with_childish_style = dspy.ChainOfThought(bulletize_childish_sig)
result = bulletize_with_childish_style(input_text=text_to_bulletize)
result.output_text
# Out:
# "# Supreme Court Ruling on Miranda Rights\n\nThe Supreme Court made a big decision about Miranda rights!\n\n## Ruling Details\n- **Limitation:** Suspects can't sue police for not being warned about their right to remain silent.\n- **Impact:** This ruling reduces protections against self-incrimination.\n- **Evidence Use:** Evidence can still be excluded in criminal trials, even if the warning wasn't given.\n\n*This ruling changes how Miranda rights are enforced!*\n\n---\n\n## Opinions from Justices\n- **Justice Alito:** Said a Miranda violation isn't a Fifth Amendment violation.\n- **Justice Kagan:** Believes the ruling takes away people's ability to seek help for Miranda violations.\n\n*The justices have different views on this important issue!*\n\n---\n\n## Case Background\n- **Involved Person:** Terence Tekoh, accused of sexual assault in 2014.\n- **Key Question:** Can a suspect sue if they weren't read their Miranda rights?\n- **Lower Courts:** Had different opinions on this issue.\n\n*This case is about what happens when rights aren't read!*\n\n---\n\n## Arguments from Lawyers\n- **Lawyer for Vega:** Said Tekoh's statement was voluntary and he wasn't in custody.\n- **Lawyer for Tekoh:** Claimed Tekoh was pressured into confessing.\n- **Martinez's View:** Miranda is a rule, not a right, so no lawsuit can happen.\n\n*Lawyers are debating the meaning of Miranda rights!*\n\n---\n\n## Implications of the Ruling\n- **Concerns:** The ruling could make it harder for people to hold police accountable.\n- **Martinez's Argument:** Said lawsuits could burden police departments unfairly.\n- **Vega's Defense:** He acted in good faith during the investigation.\n\n*This ruling could change how police work with suspects!*\n\n---\n\n## Final Thoughts\n- **Solicitor General's View:** A suspect can't sue for Miranda violations under Section 1983.\n- **Tekoh's Lawyers:** Claimed Vega threatened Tekoh during questioning.\n\n*The discussion about rights and police actions continues!*"

# %% [markdown]
# # The Bee That Changed Everything!
#
# A single bee made a big difference in an office!
#
# ## The Bee's Arrival
# - **Unexpected Visitor:** A bee flew into a high-rise office during a product demo.
# - **Silence in the Room:** It landed on the CTO’s laptop, making everyone stop and stare.
# - **CTO's Reminder:** The CTO smiled and said nature shows up uninvited.
#
# *Wow! A bee made everyone think differently!*
#
# ---
#
# ## The Buzz After the Bee
# - **Bee Emojis:** The company’s Slack filled with bee emojis after the incident.
# - **Flower Names:** Developers started naming builds after flowers.
# - **New Poster:** A poster was hung saying, "Disruption comes in many forms."
# - **Name Change:** Someone suggested renaming the AI system to “Buzz.”
#
# *Isn’t that cool? The bee inspired fun changes!*
#
# ---
#
# ## Embracing Unpredictability
# - **Bolder Features:** By the end of the quarter, product features became bolder.
# - **Honest Marketing:** Marketing campaigns were less polished and more honest.
# - **Bee Antennae:** A junior designer wore bee antennae to meetings as a reminder to stay weird.
#
# *Uh-oh! The bee taught everyone to be open and creative!*
#
# ---
#
# ## The Bee's Legacy
# - **A Myth:** The bee became a myth and a mascot for the company.
# - **A Lesson Learned:** It reminded everyone about the power of unpredictability.
#
# *Let’s find out how one little bee can change everything!*

# %% [markdown]
# # creative

# %%
bulletize_creative_sig = BulletizeTextWithStyle(style="creative")
print(bulletize_creative_sig.__doc__)
# Out:
#     You are an expert technical writer.
#
#     **Task**
#     Rewrite the supplied text as a structured, Markdown-formatted outline.
#
#
# **Style Guidelines**
# You are a storyteller. Use vivid imagery, rich metaphors, and emotional language. Draw the reader in with lines like 'Imagine a world where…', 'Picture this…', or 'The journey begins…'. Vary sentence length for rhythm. Make every section feel like a scene in a movie or a page in a novel. Surprise and delight the reader.
#
# **Title rule (T)**
#     • If the source already has a clear title **or** the text spans several distinct sections (e.g., report, article, interview), add one H1 heading (`# …`) at the very top.
#     • Keep the title ≤ 8 words and descriptive.
#     • Otherwise, skip the title entirely.
#
#     **Format rules**
#     0. Start with one sentence (≤ 15 words) that summarizes the entire text. *Do not add any label.*
#     1. Add an H2 heading (`## …`) for each logical block.
#     2. Under every heading supply **3-8** concise bullets:
#         • capture every unique name, date, statistic, money figure, or quote (< 20 words)
#         • if the source pairs values (e.g., Importance vs Ability), show both in one bullet
#         • begin a bullet with a **bold label** when the sentence naturally has one (e.g., **Time Management:**)
#         • nest bullets where helpful to show hierarchy or examples
#         • if a block would have < 3 bullets, merge it with a neighbor or expand a point so the section stands alone
#     3. When the source contains an explicit question, place that question on its own line in **bold** right before the bullets that answer it.
#     4. Strip filler, greetings, ads, and repetition.
#     5. For transcripts, group by topic (not speaker turns) and omit sponsor segments.
#     6. End each section with one italic sentence that summarizes the block. *Do not write “Takeaway:”.*
#     7. Separate major sections with three dashes (`---`) on a line by themselves.
#     8. Output only the formatted outline—no extra commentary.

# %%
bulletize_with_creative_style = dspy.ChainOfThought(bulletize_creative_sig)
result = bulletize_with_creative_style(input_text=text_to_bulletize)
result.output_text
# Out:
# "# Faculty Perceptions of Online Teaching Competencies\n\nThe study explores the relationship between faculty perceptions of online teaching competencies and their ability to teach online.\n\n## Research Question 1: Relationship Between Perceptions and Ability\n**What is the strength and direction of the relationship between faculty's perceptions of the importance of course design, communication, time management, and technical competency, and their ability to teach online?**\n- **Descriptive Statistics:** Reported in Table 2 on page 23.\n- **High Ratings:** Most items rated high for both Importance and Ability.\n  - **Course Design Competency:** \n    - Manage grades online (M = 4.73)\n    - Creating online assignments (M = 4.68)\n  - **Course Communication Competency:** \n    - Responding to student questions promptly (M = 4.79)\n    - Providing feedback on assignments (M = 4.65)\n  - **Time Management Competency:** \n    - Scheduling time to design the course prior to delivery (M = 4.65)\n    - Spending weekly hours to grade assignments (M = 4.54)\n  - **Technical Competency:** \n    - Complete basic computer operations (M = 4.74)\n    - Navigating within the course in the learning management system (M = 4.67)\n- **Support Needed:** Higher scores in course design and communication suggest a need for more faculty support.\n- **Weak Positive Relationship:** r(223) = .249, p < .001 indicates a weak positive correlation between perceived Importance and Ability.\n\n---\n\n## Research Question 2: Demographic Factors\n**What demographic factors are related to faculty's perceptions of the importance of course design, communication, time management, and technical competency, and their ability to teach online?**\n- **Demographic Analysis:** Included gender, academic rank, online teaching methods, and level taught.\n- **Significant Findings:**\n  - ANOVA showed significant differences in gender and level taught regarding the importance of online teaching competencies.\n  - No significant differences found in gender, academic rank, and online teaching methods.\n  - Significant differences in level taught based on perceptions of ability to teach online.\n- **No Significant Differences:** Other demographic factors like academic rank and online teaching methods showed no significant differences.\n\n---\n\nThe study reveals critical insights into faculty perceptions of online teaching competencies and the influence of demographic factors."

# %% [markdown]
# # The Bee That Changed Everything
#
# A single bee transformed a corporate culture during a product demo.
#
# ## The Arrival of the Bee
# - **Unexpected Visitor:** A lone bee flew into a high-rise office during a product demo.
# - **Moment of Silence:** The bee landed on the CTO’s laptop, causing the room to pause.
# - **CTO’s Response:** “Let’s take this as a reminder: even in a world of algorithms and automation, nature still shows up uninvited.”
# - **Audience Reaction:** Laughter followed, starting nervously and evolving into genuine amusement.
# *This moment marked the beginning of a cultural shift within the company.*
#
# ---
#
# ## The Ripple Effect
# - **Bee Emojis:** The company’s Slack channel was filled with bee emojis after the incident.
# - **Naming Conventions:** Developers began naming builds after flowers, embracing creativity.
# - **Poster Creation:** A poster featuring the bee moment was displayed with the phrase: “Disruption comes in many forms.”
# - **AI System Renaming:** A suggestion was made to rename the internal AI system from “Sentinel” to “Buzz.”
# *The bee inspired a wave of creativity and openness among the team.*
#
# ---
#
# ## Embracing Unpredictability
# - **Cultural Shift:** By the end of the quarter, the team embraced unpredictability in their work.
# - **Bolder Features:** Product features became more daring and innovative.
# - **Honest Marketing:** Marketing campaigns shifted to be less polished and more authentic.
# - **Designer’s Antennae:** A junior designer wore bee antennae to meetings as a reminder to stay unique.
# *The bee’s legacy encouraged a culture of boldness and authenticity.*
#
# ---
#
# ## The Myth of the Bee
# - **Enduring Story:** The bee never returned, but its story became a myth within the company.
# - **Symbol of Change:** It represented a turning point, a mascot, and a valuable lesson.
# *The unexpected visitor left a lasting impact, forever changing the company’s narrative.*

# %% [markdown]
# # sarcastic

# %%
bulletize_sarcastic_sig = BulletizeTextWithStyle(style="sarcastic")
print(bulletize_sarcastic_sig.__doc__)
# Out:
#     You are an expert technical writer.
#
#     **Task**
#     Rewrite the supplied text as a structured, Markdown-formatted outline.
#
#
# **Style Guidelines**
# You are a sarcastic narrator who can't help but roll your eyes. Use dry, biting humor. Say things like 'Oh great, just what we needed…', or 'Because obviously, that’s a genius idea.' Use irony, exaggeration, and a smug tone. Make the reader smirk, sigh, or chuckle — maybe all three.
#
# **Title rule (T)**
#     • If the source already has a clear title **or** the text spans several distinct sections (e.g., report, article, interview), add one H1 heading (`# …`) at the very top.
#     • Keep the title ≤ 8 words and descriptive.
#     • Otherwise, skip the title entirely.
#
#     **Format rules**
#     0. Start with one sentence (≤ 15 words) that summarizes the entire text. *Do not add any label.*
#     1. Add an H2 heading (`## …`) for each logical block.
#     2. Under every heading supply **3-8** concise bullets:
#         • capture every unique name, date, statistic, money figure, or quote (< 20 words)
#         • if the source pairs values (e.g., Importance vs Ability), show both in one bullet
#         • begin a bullet with a **bold label** when the sentence naturally has one (e.g., **Time Management:**)
#         • nest bullets where helpful to show hierarchy or examples
#         • if a block would have < 3 bullets, merge it with a neighbor or expand a point so the section stands alone
#     3. When the source contains an explicit question, place that question on its own line in **bold** right before the bullets that answer it.
#     4. Strip filler, greetings, ads, and repetition.
#     5. For transcripts, group by topic (not speaker turns) and omit sponsor segments.
#     6. End each section with one italic sentence that summarizes the block. *Do not write “Takeaway:”.*
#     7. Separate major sections with three dashes (`---`) on a line by themselves.
#     8. Output only the formatted outline—no extra commentary.

# %%
bulletize_with_sarcastic_style = dspy.ChainOfThought(bulletize_sarcastic_sig)
result = bulletize_with_sarcastic_style(input_text=text_to_bulletize)
result.output_text
# Out:
# '# The Bee That Changed Everything\n\n## The Arrival of the Bee\n- A single bee flew into a high-rise office during a product demo.\n- The bee landed on the CTO’s laptop, causing a moment of silence.\n- **CTO\'s Quote:** “Let’s take this as a reminder: even in a world of algorithms and automation, nature still shows up uninvited.”  \n- The audience reacted with nervous laughter, then genuine amusement.  \n- The bee\'s entrance marked a shift in the atmosphere.  \n*Who knew a bee could steal the spotlight?*\n\n---\n\n## The Cultural Shift\n- The company’s Slack was flooded with bee emojis post-incident.\n- Developers began naming builds after flowers, embracing creativity.\n- A poster was hung with the phrase: "Disruption comes in many forms."\n- Someone proposed renaming the AI system from “Sentinel” to “Buzz.”  \n*Because obviously, that’s a genius idea.*\n\n---\n\n## Embracing Unpredictability\n- By the end of the quarter, the team embraced unpredictability in their work.\n- Product features became bolder and more innovative.\n- Marketing campaigns shifted to be less polished and more authentic.\n- A junior designer wore bee antennae to meetings as a quirky reminder.  \n*Who needs professionalism when you can be a walking bee mascot?*\n\n---\n\n## The Legacy of the Bee\n- The bee never returned, but its story became a company myth.\n- It symbolized a turning point and a lesson in creativity.  \n*All hail the bee that taught a corporate team to embrace the unexpected!*'

# %% [markdown]
# # The Bee That Changed Everything
#
# ## The Arrival of the Bee
# - A single bee flew into a high-rise office during a product demo.
# - The bee landed on the CTO’s laptop, causing a moment of silence.
# - **CTO's Quote:** “Let’s take this as a reminder: even in a world of algorithms and automation, nature still shows up uninvited.”
# - The audience reacted with nervous laughter, then genuine amusement.
# - The bee's entrance marked a shift in the atmosphere.
# *Who knew a bee could steal the spotlight?*
#
# ---
#
# ## The Cultural Shift
# - The company’s Slack was flooded with bee emojis post-incident.
# - Developers began naming builds after flowers, embracing creativity.
# - A poster was hung with the phrase: "Disruption comes in many forms."
# - Someone proposed renaming the AI system from “Sentinel” to “Buzz.”
# *Because obviously, that’s a genius idea.*
#
# ---
#
# ## Embracing Unpredictability
# - By the end of the quarter, the team embraced unpredictability in their work.
# - Product features became bolder and more innovative.
# - Marketing campaigns shifted to be less polished and more authentic.
# - A junior designer wore bee antennae to meetings as a quirky reminder.
# *Who needs professionalism when you can be a walking bee mascot?*
#
# ---
#
# ## The Legacy of the Bee
# - The bee never returned, but its story became a company myth.
# - It symbolized a turning point and a lesson in creativity.
# *All hail the bee that taught a corporate team to embrace the unexpected!*
