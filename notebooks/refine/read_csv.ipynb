# %%
import pandas as pd

# Read the CSV file from root directory
# df = pd.read_csv("../../r_001_3_creative.csv")
df = pd.read_csv("../../data/documents_train_original.csv")
# df = pd.read_csv("../../refinement_results.csv")
df
# Out:
#       Unnamed: 0                                        resource_id  \
# 0          43917  c8bec9e5-88ee-508c-9e17-19a2b250646b_Light the...
# 1           8077  8f80547a-a393-56b0-a194-4d81d46d9b4e_Guiding p...
# 2           4295  f8d6f6a2-54cc-53b2-b6b7-5feffd442b5e_The Devel...
# 3          21567  77cb6a46-d29b-500d-b423-f87391c87aa3_Healing Tips
# 4          19902                                   ubd82owskojrb6gk
# ...          ...                                                ...
# 2995       11192  c1a3c4d1-fcaa-51bf-9bf2-8d829addb52c_3  Intern...
# 2996        9642  ef790c8a-e24c-5089-bfb6-bd00b2cdb682_4. Materi...
# 2997       52085      bd2126db-e8d6-53b5-bf5e-2f0a494b1e04_RESEARCH
# 2998       17167  88528e28-46c4-5e7c-bb96-817990b1802b_Introduction
# 2999       63615   c8570f8f-6a6b-5ab0-b749-dae67d653321_Limitations
#
#       user_write_purpose (work, school, personal)      user_profession  \
# 0                                             NaN  researcher/academia
# ...

# %%
example_005 = df[df['id'] == "51a1f095-cda5-4691-9a41-07da40242b90"]

example_005
# Out:
#      Unnamed: 0       resource_id  \
# 993       29507  tohbelok5ck7bf1u
#
#      user_write_purpose (work, school, personal) user_profession     title  \
# 993                                          NaN   it specialist  Turkcell
#
#                                               resource  \
# 993  15 Apr 2020\n                   Turkish mobile...
#
#                                        id user_write_purpose  \
# 993  51a1f095-cda5-4691-9a41-07da40242b90               work
#
#     user_kyc_profession
# 993       it specialist

# %%
example_005.to_csv("example_005.csv", index=False)
