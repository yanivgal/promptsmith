# %%
import pandas as pd

# Read the CSV file from root directory
df = pd.read_csv("../../refinement_10_examples.csv")
df
# Out:
#      example_id                                              title  \
# 0   example_001                          Railroad Bridge Execution
# 1   example_001                          Railroad Bridge Execution
# 2   example_002                                    Lithic Analysis
# 3   example_002                                    Lithic Analysis
# 4   example_003    Designing Transformational Customer Experiences
# 5   example_003    Designing Transformational Customer Experiences
# 6   example_003    Designing Transformational Customer Experiences
# 7   example_003    Designing Transformational Customer Experiences
# 8   example_003    Designing Transformational Customer Experiences
# 9   example_003    Designing Transformational Customer Experiences
# 10  example_004                                    1. Introduction
# 11  example_004                                    1. Introduction
# 12  example_004                                    1. Introduction
# ...
